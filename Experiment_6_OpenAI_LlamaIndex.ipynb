# %%
# Import necessary libraries
import os
import json
import PyPDF2
from typing import List, Dict
import pandas as pd
from dotenv import load_dotenv

# LlamaIndex imports
from llama_index.core import Document, Settings, VectorStoreIndex, ServiceContext
from llama_index.core.node_parser import SimpleNodeParser
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI

# Load environment variables from .env file
load_dotenv()

# Verify OpenAI API key is set
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("Please set the OPENAI_API_KEY environment variable")
    
print("Environment setup complete!")
# Out:
# Environment setup complete!

# %%
# Set up LlamaIndex settings with OpenAI LLM and Embeddings
def initialize_settings():
    # Configure the embedding model (text-embedding-3-small)
    embed_model = OpenAIEmbedding(
        model="text-embedding-3-small",
        api_key=os.getenv("OPENAI_API_KEY"),
        dimensions=1536
    )
    
    # Configure the LLM (gpt-4o-mini)
    llm = OpenAI(
        model="gpt-4o-mini",
        temperature=0.1,
        api_key=os.getenv("OPENAI_API_KEY")
    )
    
    # Set up LlamaIndex settings using the new approach
    Settings.embed_model = embed_model
    Settings.llm = llm
    Settings.chunk_size = 1000
    Settings.chunk_overlap = 200
    
    # Don't return a ServiceContext object
    return Settings

# Initialize settings
settings = initialize_settings()

# Test the LLM
llm = Settings.llm
response = llm.complete("Hello, can you tell me what model you are?")
print("LLM Test Response:", response)
# Out:
# LLM Test Response: I am based on OpenAI's GPT-3 model. How can I assist you today?

# %%
# Step 6: Loading and Processing PDF Documents
def extract_text_from_pdf(pdf_path):
    """
    Extract text from a PDF file using PyPDF2
    """
    try:
        with open(pdf_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            text = ""
            for page_num in range(len(reader.pages)):
                text += reader.pages[page_num].extract_text() + "\n"
            return text
    except Exception as e:
        print(f"Error extracting text from PDF: {e}")
        return None

def load_documents_from_pdfs(pdf_paths):
    """
    Load and process PDFs into LlamaIndex Document objects
    """
    documents = {}
    for doc_type, pdf_path in pdf_paths.items():
        try:
            print(f"Loading {doc_type} from {pdf_path}...")
            text = extract_text_from_pdf(pdf_path)
            if text:
                # Create a LlamaIndex Document
                documents[doc_type] = Document(text=text, metadata={"source": pdf_path, "type": doc_type})
                
                # Save extracted text to a file for verification
                with open(f"extracted_{doc_type}.txt", "w") as f:
                    f.write(text)
                print(f"Saved extracted text to 'extracted_{doc_type}.txt'")
            else:
                print(f"Failed to extract text from {pdf_path}")
        except Exception as e:
            print(f"Error processing {pdf_path}: {e}")
    
    return documents

# Define PDF paths
pdf_paths = {
    "requirements": "Requirements_Specification.pdf",
    "task_estimates": "SampleProjectTasksEstimates.pdf"
}

# Load documents
documents = load_documents_from_pdfs(pdf_paths)

# Print extracted documents statistics
for doc_type, doc in documents.items():
    print(f"\n{doc_type.capitalize()} document:")
    print(f"Length: {len(doc.text)} characters")
    print(f"Preview: {doc.text[:300]}...")

# Store full text separately for direct use
document_store = {
    f"{doc_type}_full": doc.text for doc_type, doc in documents.items()
}
# Out:
# Loading requirements from Requirements_Specification.pdf...
# Saved extracted text to 'extracted_requirements.txt'
# Loading task_estimates from SampleProjectTasksEstimates.pdf...
# Saved extracted text to 'extracted_task_estimates.txt'
#
# Requirements document:
# Length: 4994 characters
# Preview:
# Chicago WideCast
# Smart -Home Services
#
#
#
#
#
# Author: Atef Bader, PhD
# Last Edit: 7/5/2024
# Image/Model: dall-e-3
#
#
# Project Overview Statement:
#
# Chicago WideCast Smart -Home Services  is a startup company that is
# interested in automating all of its business process workflows utilizi...
#
# Task_estimates document:
# Length: 2305 characters
# Preview:
# Task  Amount of Work  Productivity  Rate
# Project Plan
# Write Plan  56 pages  5 page s/Hour
# Review Plan
# Preparation for review    4 pages/Hour
# Review Meeting   8 pages/Hour
# Rework  39 defects  5 defects/Hour
#
# Risk Mitigation and Contingency Plan
# Write Plan  78 pages  5...

# %%
# Create vector indices for each document type
def create_vector_indices(documents):
    indices = {}
    for doc_type, doc in documents.items():
        print(f"Creating vector index for {doc_type}...")
        # Parse the document into nodes
        parser = SimpleNodeParser.from_defaults()
        nodes = parser.get_nodes_from_documents([doc])
        
        # Create a vector index
        # Uses the global Settings instead of passing service_context
        index = VectorStoreIndex(nodes)
        indices[doc_type] = index
        
        # Save the index for future use
        index.storage_context.persist(f"{doc_type}_index")
        
    return indices

# Create vector indices
indices = create_vector_indices(documents)

# Create query engines for each index
query_engines = {
    doc_type: index.as_query_engine() 
    for doc_type, index in indices.items()
}

# Test the query engines
test_queries = {
    "requirements": "What TV plans does WideCast offer?",
    "task_estimates": "What are the productivity rates for writing plans?"
}

for doc_type, query in test_queries.items():
    print(f"\n{doc_type.capitalize()} query: '{query}'")
    response = query_engines[doc_type].query(query)
    print(f"Response: {response}")
# Out:
# Creating vector index for requirements...
# Creating vector index for task_estimates...
#
# Requirements query: 'What TV plans does WideCast offer?'
# Response: WideCast offers the following TV plans:
#
# 1. Basic - 50 channels
# 2. BasicPlus – 100 channels
# 3. Ultimate - 200 channels
#
# Task_estimates query: 'What are the productivity rates for writing plans?'
# Response: The productivity rates for writing plans are as follows:
#
# - Project Plan: 5 pages per hour
# - Risk Mitigation and Contingency Plan: 5 pages per hour
# - Analysis Document: 5 pages per hour
# - Design Document (DD): 4 pages per hour
# - Test Plan (TP): 6 pages per day

# %%
# Define role-specific prompts
role_prompts = {
    "project_manager": """You are an experienced Project Manager. Your task is to create a detailed project plan 
    for the Chicago WideCast Smart-Home Services system based on the requirements provided. 
    Tag and number each requirement/use-case with unique identifiers. 
    Use the SampleProjectTasksEstimates.pdf format when creating tasks and estimates.""",
    
    "requirements_engineer": """You are a skilled Requirements Engineer. Your task is to analyze the provided 
    requirements for the Chicago WideCast Smart-Home Services system and create detailed, tagged, and numbered 
    requirements and use cases. Follow a standard format like REQ-001, REQ-002, etc., for requirements 
    and UC-001, UC-002, etc., for use cases.""",
    
    "system_engineer": """You are an experienced System Engineer. Review the requirements for the Chicago WideCast 
    Smart-Home Services system and create system architecture tasks with time estimates. 
    Consider integration points, system components, and technical constraints.""",
    
    "software_engineer": """You are a Software Engineer responsible for implementing the Chicago WideCast 
    Smart-Home Services system. Create coding tasks and estimates based on the requirements. 
    Consider frontend, backend, database, and API development tasks.""",
    
    "test_engineer": """You are a Test Engineer responsible for ensuring the quality of the Chicago WideCast 
    Smart-Home Services system. Create testing tasks and estimates covering unit tests, integration tests, 
    system tests, and user acceptance tests.""",
    
    "documentation_engineer": """You are a Documentation Engineer responsible for creating all documentation 
    for the Chicago WideCast Smart-Home Services system. Create documentation tasks and estimates covering 
    user manuals, system documentation, API documentation, and training materials."""
}

# Define the roles
roles = ["project_manager", "requirements_engineer", "system_engineer", 
         "software_engineer", "test_engineer", "documentation_engineer"]

# %%
# Function to generate tagged requirements using the Requirements Engineer prompt
def generate_tagged_requirements():
    # Get the full requirements document
    full_requirements = document_store["requirements_full"]
    
    # Get the requirements engineer system prompt
    system_message = role_prompts["requirements_engineer"]
    
    # Create a structured prompt
    prompt = f"""
    {system_message}
    
    Based on the following Chicago WideCast Smart-Home Services requirements document, 
    create a comprehensive list of tagged and numbered requirements and use cases. 
    Format each requirement as REQ-XXX with a descriptive title and detailed description,
    and each use case as UC-XXX with a descriptive title and detailed description.
    
    Requirements Document:
    {full_requirements}
    
    Focus on extracting the actual requirements from the document rather than inventing new ones.
    Ensure each requirement is specific, measurable, achievable, relevant, and time-bound (SMART).
    """
    
    # Query using LlamaIndex
    llm = Settings.llm
    response = llm.complete(prompt)
    return response

# Generate tagged requirements
print("Generating tagged requirements...")
tagged_requirements = generate_tagged_requirements()

print("\nTagged Requirements Preview:")
print(tagged_requirements)
# Out:
# Generating tagged requirements...
#
# Tagged Requirements Preview:
# Based on the provided requirements document for the Chicago WideCast Smart-Home Services system, here is a comprehensive list of tagged and numbered requirements and use cases.
#
# ### Requirements
#
# #### REQ-001: Service Offerings
# **Description:** The system shall provide the following service offerings to customers:
# - Online TV plans: Basic (50 channels), BasicPlus (100 channels), Ultimate (200 channels).
# - Data plans: WiFi SpeedLane (100/5 Mbps), WiFi LightLane (250/30 Mbps).
# - On-Demand Movie Streaming: Premium (100 movies/month), Ultimate (500 movies/month).
# - Pay-Per-View (PPV) services: Live Sports Events and PPV Movies.
# - Online Video Games: Premium (100 games/month), Ultimate (200 games/month).
# - Home Security services: Security Cameras and Alarms, Remote Lock/Unlock for delivery personnel.
# - Utilities: Remote control for lighting and thermostat.
#
# #### REQ-002: User Roles
# **Description:** The system shall support four user roles: Managers, Account Specialists, Technical Support Specialists, and Customers, each with specific permissions and capabilities.
#
# #### REQ-003: Manager Capabilities
# **Description:** The system shall allow Managers to execute the following workflows:
# 1. Add any products/services offered.
# 2. Update any products/services offered.
# 3. Delete any products/services offered.
# 4. Cancel any type of order.
# 5. Update any type of order.
# 6. Delete any type of order.
#
# #### REQ-004: Account Specialist Capabilities
# **Description:** The system shall allow Account Specialists to execute the following workflows:
# 1. Create an account for a new customer.
# 2. Update customer account information.
# 3. Create an incident ticket and assign it to a technician.
# 4. Place an order for a PPV event.
#
# #### REQ-005: Technical Support Specialist Capabilities
# **Description:** The system shall allow Technical Support Specialists to execute the following workflows:
# 1. Schedule incident tickets.
# 2. Close incident tickets.
# 3. Cancel incident tickets.
#
# #### REQ-006: Customer Capabilities
# **Description:** The system shall allow customers with existing accounts to execute the following workflows:
# 1. Update personal account information (credit card, personal info, etc.).
# 2. Pay monthly bills.
# 3. Create an order for any of the products/services offered.
# 4. Change an order for any of the products/services offered.
# 5. Cancel an order for any of the products/services offered.
#
# #### REQ-007: Customer Requirements
# **Description:** The system shall enforce the following business rules and constraints:
# 1. New customers must rent the WideCast Smarthub Box and the necessary devices for the services purchased.
# 2. Customers must have either a Data plan, Online TV plan, or both.
# 3. Customers can choose between a monthly plan, a 1-year contract, or a 2-year contract.
# 4. An Online TV plan is required to provide PPV services.
# 5. A Data plan is required for On-Demand Movie Streaming, Online Video Games, Home Security, and Utilities.
#
# #### REQ-008: Contract Options
# **Description:** The system shall provide customers with the following contract options:
# 1. TV plan (Monthly Contract).
# 2. Data plan (Monthly Contract).
# 3. TV plan and Data plan (Monthly Contract).
# 4. TV plan (1-Year Contract) with one free PPV movie weekly.
# 5. Data plan (1-Year Contract) with one free month of Premium Online Video Games.
# 6. TV plan and Data plan (1-Year Contract) with two free PPV movies weekly, one free month of Premium Online Video Games, and one free month of Premium On-Demand Movie Streaming.
# 7. TV plan and Data plan (2-Year Contract) with two free PPV movies weekly, two free months of Premium Online Video Games, two free months of Premium On-Demand Movie Streaming, and free remote control for Lighting and Thermostat.
# 8. TV plan, Data plan, and Home Security (2-Year Contract) with the same benefits as above plus additional free services.
#
# ### Use Cases
#
# #### UC-001: Manage Products and Services
# **Description:** This use case allows Managers to add, update, or delete products and services offered by WideCast. The Manager selects the action (add, update, delete), specifies the product/service details, and confirms the action.
#
# #### UC-002: Customer Account Management
# **Description:** This use case allows Account Specialists to create and update customer accounts. The Account Specialist inputs customer information, verifies it, and saves the account details.
#
# #### UC-003: Incident Ticket Management
# **Description:** This use case allows Technical Support Specialists to schedule, close, or cancel incident tickets. The Specialist selects the ticket, chooses the action, and confirms the changes.
#
# #### UC-004: Customer Order Management
# **Description:** This use case allows customers to create, change, or cancel orders for products/services. The customer logs into their account, selects the desired action, and follows the prompts to complete the order management process.
#
# #### UC-005: Payment Processing
# **Description:** This use case allows customers to pay their monthly bills. The customer logs into their account, navigates to the billing section, selects the payment method, and confirms the payment.
#
# #### UC-006: Contract Selection
# **Description:** This use case allows customers to select a contract option for their services. The customer reviews available contracts, selects one, and confirms their choice, receiving the associated benefits.
#
# This structured approach ensures that all requirements and use cases are clearly defined and traceable, facilitating the development and implementation of the Chicago WideCast Smart-Home Services system.
#
# Tagged requirements saved to 'tagged_requirements_exp6.txt'

# %%
# Function to generate task estimates for each role
def generate_tasks_and_estimates(role):
    # Get the full documents
    full_requirements = document_store["requirements_full"]
    full_task_estimates = document_store["task_estimates_full"]
    
    # Get the role-specific system prompt
    system_message = role_prompts[role]
    
    # Create a structured prompt
    prompt = f"""
    {system_message}
    
    Based on the following Chicago WideCast Smart-Home Services requirements document and 
    the SampleProjectTasksEstimates format, generate a detailed list of tasks 
    and time estimates for your role as a {role.replace('_', ' ').title()}.
    
    Requirements Document:
    {full_requirements}
    
    Sample Task Estimates Format:
    {full_task_estimates}
    
    Include:
    1. Task descriptions
    2. Estimated work amounts
    3. Productivity rates
    
    Format your response as a structured table similar to the sample provided.
    Be specific about the tasks relevant to your role and provide realistic estimates.
    """
    
    # Query using LlamaIndex
    llm = Settings.llm
    response = llm.complete(prompt)
    return response

# Generate tasks and estimates for each role
tasks_and_estimates = {}
for role in roles:
    print(f"\nGenerating tasks for: {role}")
    try:
        tasks = generate_tasks_and_estimates(role)
        tasks_and_estimates[role] = tasks
        
        # Print preview of results
        print(f"\n=== {role.replace('_', ' ').title()} Tasks and Estimates Preview ===")
        print(tasks)
        
        # # Save each role's tasks to a file
        # with open(f"{role}_tasks_exp6.txt", "w") as f:
        #     f.write(tasks)
        
        print(f"Tasks for {role} saved to '{role}_tasks_exp6.txt'")
    except Exception as e:
        print(f"Error processing role {role}: {e}")
        tasks_and_estimates[role] = f"Error generating tasks: {str(e)}"
# Out:
# Generating tasks for: project_manager
#
# === Project Manager Tasks and Estimates Preview ===
# Here is a detailed project plan for the Chicago WideCast Smart-Home Services system, structured in a table format similar to the SampleProjectTasksEstimates.pdf format. Each task is tagged and numbered with unique identifiers based on the requirements provided.
#
# | Task ID | Task Description                                      | Amount of Work         | Productivity Rate         |
# |---------|------------------------------------------------------|------------------------|---------------------------|
# | PM-01   | Project Plan                                          | 60 pages               | 5 pages/Hour              |
# | PM-02   | Write Project Overview Statement                      | 5 pages                | 4 pages/Hour              |
# | PM-03   | Review Project Plan                                   |                        |                           |
# | PM-03.1 | Preparation for review                                | 4 pages                | 4 pages/Hour              |
# | PM-03.2 | Review Meeting                                        | 8 pages                | 6 pages/Hour              |
# | PM-03.3 | Rework                                                | 10 defects             | 5 defects/Hour            |
# | PM-04   | Risk Mitigation and Contingency Plan                 | 80 pages               | 5 pages/Hour              |
# | PM-05   | Write Requirements Document                           | 200 requirements        | 4 requirements/Hour       |
# | PM-06   | Write Use Case Model                                  | 70 use cases           | 5 use cases/2 Hours       |
# | PM-07   | Review Requirements / Use Case Model                  |                        |                           |
# | PM-07.1 | Preparation for review                                | 20 requirements        | 4 requirements/Hour       |
# | PM-07.2 | Review Meeting                                        | 30 requirements        | 5 requirements/Hour       |
# | PM-07.3 | Rework                                                | 150 defects            | 8 defects/Hour            |
# | PM-08   | Write Analysis Document                               | 75 pages               | 5 pages/Hour              |
# | PM-09   | Review Analysis Document                              |                        |                           |
# | PM-09.1 | Preparation for Analysis Document                     | 5 pages                | 4 pages/Hour              |
# | PM-09.2 | Review Meeting                                        | 10 pages               | 7 pages/Hour              |
# | PM-09.3 | Rework                                                | 100 defects            | 5 defects/Hour            |
# | PM-10   | Write Design Document                                 | 80 pages               | 4 pages/Hour              |
# | PM-11   | Review Design Document                                |                        |                           |
# | PM-11.1 | Preparation for Design Document                       | 5 pages                | 5 pages/Hour              |
# | PM-11.2 | Review Meeting                                        | 10 pages               | 9 pages/Hour              |
# | PM-11.3 | Rework                                                | 200 defects            | 4 defects/Hour            |
# | PM-12   | Write Data Model (DM)                                | 35 pages               | 1 page/3 Hours            |
# | PM-13   | Review Data Model                                     |                        |                           |
# | PM-13.1 | Preparation for Data Model                            | 5 pages                | 5 pages/Hour              |
# | PM-13.2 | Review Meeting                                        | 5 pages                | 4 pages/Hour              |
# | PM-13.3 | Rework                                                | 80 defects             | 7 defects/Hour            |
# | PM-14   | Write Code for Conversational AI Assistant            | 4000 SLOC              | 5 SLOC/Hour               |
# | PM-15   | Unit Testing                                          |                        |                           |
# | PM-15.1 | Prepare/Execute Test Cases                            | 200 test cases         | 8 Test Cases/Day          |
# | PM-15.2 | Fix Found Defects                                     | 200 defects            | 7 Defects/Day             |
# | PM-15.3 | Test Fixed Defects                                    | 200 defects            | 6 Defects/Day             |
# | PM-16   | Code Inspection                                       |                        |                           |
# | PM-16.1 | Preparation for Code Inspection                       | 150 SLOC               | 124 SLOC/Hour             |
# | PM-16.2 | Code Inspection Meeting                               | 250 SLOC               | 210 SLOC/Hour             |
# | PM-16.3 | Rework                                                | 180 defects            | 4 defects/Hour            |
# | PM-17   | Write Test Plan (TP)                                 | 220 pages              | 6 pages/Day               |
# | PM-18   | Review Test Plan                                      |                        |                           |
# | PM-18.1 | Preparation for Test Plan                             | 5 pages                | 5 pages/Hour              |
# | PM-18.2 | Review TP Meeting                                     | 10 pages               | 8 pages/Hour              |
# | PM-18.3 | Rework                                                | 300 defects            | 6 defects/Hour            |
# | PM-19   | Execute Test Plan (test cases)                       | 300 test cases         | 8 test cases/Day          |
# | PM-20   | Fix Found Defects                                     | 200 defects            | 9 defects/Day             |
# | PM-21   | Test Fixed Defects                                    | 200 defects            | 13 defects/Day            |
# | PM-22   | Write User Documentation                              | 150 pages              | 4 pages/Hour              |
# | PM-23   | Review User Documentation                             |                        |                           |
# | PM-23.1 | Preparation for User Documentation Review             | 5 pages                | 4 pages/Hour              |
# | PM-23.2 | Review UD Meeting                                     | 10 pages               | 6 pages/Hour              |
# | PM-23.3 | Rework                                                | 170 defects            | 8 defects/Hour            |
#
# This table outlines the tasks relevant to the role of a Project Manager for the Chicago WideCast Smart-Home Services system, along with estimated work amounts and productivity rates. Each task is designed to ensure the successful planning, execution, and delivery of the project.
# Tasks for project_manager saved to 'project_manager_tasks_exp6.txt'
#
# Generating tasks for: requirements_engineer
#
# === Requirements Engineer Tasks and Estimates Preview ===
# Here is a structured table detailing the tasks and time estimates for the role of a Requirements Engineer for the Chicago WideCast Smart-Home Services system, following the format provided in the Sample Task Estimates.
#
# | Task Description                                   | Amount of Work       | Productivity Rate        |
# |----------------------------------------------------|----------------------|---------------------------|
# | **Requirement Gathering**                           |                      |                           |
# | Conduct Interviews with Stakeholders                | 10 interviews        | 1 interview/2 hours       |
# | Distribute and Analyze Questionnaires               | 5 questionnaires     | 1 questionnaire/1 hour     |
# | Review Existing Documentation                        | 20 documents         | 1 document/1 hour         |
# | **Requirement Specification**                       |                      |                           |
# | Write Functional Requirements                       | 50 requirements      | 4 requirements/hour       |
# | Write Non-Functional Requirements                   | 30 requirements      | 3 requirements/hour       |
# | Write Business Rules                                | 15 rules             | 2 rules/hour              |
# | **Use Case Development**                            |                      |                           |
# | Identify Actors and Use Cases                       | 20 use cases         | 2 use cases/hour          |
# | Write Use Case Descriptions                         | 20 use cases         | 1 use case/1 hour         |
# | **Review and Validation**                           |                      |                           |
# | Prepare Requirements for Review                     | 100 requirements      | 10 requirements/hour      |
# | Conduct Review Meetings                             | 5 meetings           | 1 meeting/2 hours         |
# | Rework Requirements Based on Feedback               | 30 defects           | 5 defects/hour            |
# | **Traceability and Documentation**                  |                      |                           |
# | Create Requirements Traceability Matrix             | 1 matrix             | 4 hours                   |
# | Document Changes and Version Control                | 1 document           | 3 hours                   |
# | **Stakeholder Communication**                       |                      |                           |
# | Prepare Status Reports                              | 5 reports            | 1 report/2 hours          |
# | Conduct Stakeholder Feedback Sessions                | 3 sessions           | 1 session/2 hours         |
# | **Final Review and Sign-off**                      |                      |                           |
# | Finalize Requirements Document                      | 1 document           | 4 hours                   |
# | Obtain Sign-off from Stakeholders                   | 1 document           | 2 hours                   |
#
# ### Summary of Total Estimated Work
# - **Total Hours for Requirement Gathering**: 30 hours
# - **Total Hours for Requirement Specification**: 20 hours
# - **Total Hours for Use Case Development**: 40 hours
# - **Total Hours for Review and Validation**: 20 hours
# - **Total Hours for Traceability and Documentation**: 7 hours
# - **Total Hours for Stakeholder Communication**: 10 hours
# - **Total Hours for Final Review and Sign-off**: 6 hours
#
# ### Grand Total Estimated Hours: 133 hours
#
# This structured approach ensures that all aspects of the requirements engineering process are covered, from gathering initial requirements to finalizing documentation and obtaining stakeholder approval.
# Tasks for requirements_engineer saved to 'requirements_engineer_tasks_exp6.txt'
#
# Generating tasks for: system_engineer
#
# === System Engineer Tasks and Estimates Preview ===
# Here is a structured table outlining the system architecture tasks for the Chicago WideCast Smart-Home Services system, along with estimated work amounts and productivity rates:
#
# | Task Description                                   | Amount of Work         | Productivity Rate         |
# |----------------------------------------------------|------------------------|---------------------------|
# | **Project Planning**                               |                        |                           |
# | Write Project Plan                                 | 30 pages               | 5 pages/Hour              |
# | Review Project Plan                                |                        |                           |
# | Preparation for Review                             | 5 pages                | 4 pages/Hour              |
# | Review Meeting                                     | 10 pages               | 6 pages/Hour              |
# | Rework                                             | 15 defects             | 5 defects/Hour            |
# | **Requirements Analysis**                          |                        |                           |
# | Gather Detailed Requirements                        | 100 requirements       | 4 requirements/Hour       |
# | Write Requirements Document                         | 50 pages               | 5 pages/Hour              |
# | Review Requirements Document                        |                        |                           |
# | Preparation for Review                             | 10 pages               | 4 pages/Hour              |
# | Review Meeting                                     | 15 pages               | 6 pages/Hour              |
# | Rework                                             | 20 defects             | 5 defects/Hour            |
# | **System Design**                                  |                        |                           |
# | Create High-Level Architecture Diagram             | 1 diagram              | 8 hours                   |
# | Write Detailed Design Document                      | 60 pages               | 4 pages/Hour              |
# | Review Design Document                             |                        |                           |
# | Preparation for Review                             | 10 pages               | 4 pages/Hour              |
# | Review Meeting                                     | 15 pages               | 6 pages/Hour              |
# | Rework                                             | 25 defects             | 5 defects/Hour            |
# | **Integration Planning**                           |                        |                           |
# | Identify Integration Points                         | 10 integration points   | 2 points/Hour             |
# | Create Integration Plan                            | 20 pages               | 4 pages/Hour              |
# | Review Integration Plan                            |                        |                           |
# | Preparation for Review                             | 5 pages                | 4 pages/Hour              |
# | Review Meeting                                     | 10 pages               | 6 pages/Hour              |
# | Rework                                             | 10 defects             | 5 defects/Hour            |
# | **Technical Constraints Analysis**                 |                        |                           |
# | Identify Technical Constraints                      | 15 constraints         | 3 constraints/Hour        |
# | Document Technical Constraints                      | 20 pages               | 4 pages/Hour              |
# | Review Technical Constraints Document               |                        |                           |
# | Preparation for Review                             | 5 pages                | 4 pages/Hour              |
# | Review Meeting                                     | 10 pages               | 6 pages/Hour              |
# | Rework                                             | 5 defects              | 5 defects/Hour            |
# | **Risk Management**                                |                        |                           |
# | Identify Risks                                     | 20 risks               | 4 risks/Hour              |
# | Create Risk Mitigation Plan                        | 15 pages               | 4 pages/Hour              |
# | Review Risk Mitigation Plan                        |                        |                           |
# | Preparation for Review                             | 5 pages                | 4 pages/Hour              |
# | Review Meeting                                     | 10 pages               | 6 pages/Hour              |
# | Rework                                             | 10 defects             | 5 defects/Hour            |
# | **Documentation**                                  |                        |                           |
# | Create System Documentation                        | 100 pages              | 4 pages/Hour              |
# | Review System Documentation                        |                        |                           |
# | Preparation for Review                             | 10 pages               | 4 pages/Hour              |
# | Review Meeting                                     | 15 pages               | 6 pages/Hour              |
# | Rework                                             | 20 defects             | 5 defects/Hour            |
#
# This table provides a comprehensive breakdown of tasks relevant to the role of a System Engineer for the Chicago WideCast Smart-Home Services system, including time estimates and productivity rates for each task.
# Tasks for system_engineer saved to 'system_engineer_tasks_exp6.txt'
#
# Generating tasks for: software_engineer
#
# === Software Engineer Tasks and Estimates Preview ===
# Here is a detailed list of tasks and time estimates for the Chicago WideCast Smart-Home Services system, structured in a table format similar to the provided sample:
#
# | Task Description                                   | Amount of Work         | Productivity Rate          |
# |----------------------------------------------------|------------------------|----------------------------|
# | **Project Planning**                               |                        |                            |
# | Write Project Plan                                 | 30 pages               | 5 pages/Hour              |
# | Review Project Plan                                |                        |                            |
# | Preparation for Review                             | 5 pages                | 4 pages/Hour              |
# | Review Meeting                                     | 10 pages               | 6 pages/Hour              |
# | Rework                                             | 15 defects             | 5 defects/Hour            |
# | **Requirements Gathering**                         |                        |                            |
# | Write Functional Requirements                       | 100 requirements       | 4 requirements/Hour       |
# | Write Non-Functional Requirements                  | 50 requirements        | 4 requirements/Hour       |
# | Review Requirements                                |                        |                            |
# | Preparation for Review                             | 20 requirements        | 5 requirements/Hour       |
# | Review Meeting                                     | 30 requirements        | 6 requirements/Hour       |
# | Rework                                             | 25 defects             | 8 defects/Hour            |
# | **System Design**                                  |                        |                            |
# | Write System Architecture Document                 | 40 pages               | 4 pages/Hour              |
# | Write Database Design Document                     | 30 pages               | 3 pages/Hour              |
# | Review Design Documents                            |                        |                            |
# | Preparation for Review                             | 10 pages               | 5 pages/Hour              |
# | Review Meeting                                     | 15 pages               | 6 pages/Hour              |
# | Rework                                             | 20 defects             | 4 defects/Hour            |
# | **Frontend Development**                           |                        |                            |
# | Develop User Interface for Customer Portal        | 200 SLOC               | 5 SLOC/Hour               |
# | Develop User Interface for Admin Portal           | 150 SLOC               | 5 SLOC/Hour               |
# | Unit Testing UI Components                         | 50 test cases          | 8 test cases/Day          |
# | Fix Found Defects in UI                           | 30 defects             | 7 defects/Day             |
# | **Backend Development**                            |                        |                            |
# | Develop API for Customer Account Management        | 500 SLOC               | 5 SLOC/Hour               |
# | Develop API for Order Management                   | 600 SLOC               | 5 SLOC/Hour               |
# | Develop API for Incident Ticket Management         | 400 SLOC               | 5 SLOC/Hour               |
# | Unit Testing API Endpoints                         | 100 test cases         | 8 test cases/Day          |
# | Fix Found Defects in API                           | 40 defects             | 7 defects/Day             |
# | **Database Development**                           |                        |                            |
# | Design Database Schema                             | 1 Schema               | 10 hours                  |
# | Implement Database Schema                          | 1 Schema               | 15 hours                  |
# | Write SQL Queries for CRUD Operations              | 50 queries             | 2 queries/Hour            |
# | Test Database Queries                              | 50 test cases          | 8 test cases/Day          |
# | Fix Found Defects in Database                      | 20 defects             | 6 defects/Day             |
# | **Testing**                                        |                        |                            |
# | Write Test Plan for System Testing                 | 30 pages               | 6 pages/Day               |
# | Execute Test Cases                                 | 200 test cases         | 8 test cases/Day          |
# | Fix Found Defects                                  | 50 defects             | 9 defects/Day             |
# | Test Fixed Defects                                 | 50 defects             | 13 defects/Day            |
# | **Documentation**                                  |                        |                            |
# | Write User Documentation                           | 100 pages              | 4 pages/Hour              |
# | Review User Documentation                          |                        |                            |
# | Preparation for Review                             | 20 pages               | 4 pages/Hour              |
# | Review Meeting                                     | 30 pages               | 6 pages/Hour              |
# | Rework                                             | 25 defects             | 8 defects/Hour            |
#
# This table outlines the tasks relevant to the role of a Software Engineer in the Chicago WideCast Smart-Home Services project, along with realistic estimates for the amount of work and productivity rates.
# Tasks for software_engineer saved to 'software_engineer_tasks_exp6.txt'
#
# Generating tasks for: test_engineer
#
# === Test Engineer Tasks and Estimates Preview ===
# Here is a structured table with testing tasks and estimates for the Chicago WideCast Smart-Home Services system, formatted similarly to the provided sample:
#
# | Task Description                                   | Amount of Work         | Productivity Rate         |
# |----------------------------------------------------|------------------------|---------------------------|
# | **Unit Testing**                                   |                        |                           |
# | Write Unit Test Cases for Services                 | 120 test cases         | 8 test cases/day          |
# | Execute Unit Test Cases                            | 120 test cases         | 10 test cases/day         |
# | Fix Found Defects in Unit Tests                    | 30 defects             | 6 defects/day             |
# | Test Fixed Defects in Unit Tests                   | 30 defects             | 8 defects/day             |
# | **Integration Testing**                             |                        |                           |
# | Write Integration Test Cases                        | 80 test cases          | 6 test cases/day          |
# | Execute Integration Test Cases                     | 80 test cases          | 5 test cases/day          |
# | Fix Found Defects in Integration Tests              | 25 defects             | 5 defects/day             |
# | Test Fixed Defects in Integration Tests             | 25 defects             | 7 defects/day             |
# | **System Testing**                                 |                        |                           |
# | Write System Test Plan                             | 50 pages               | 5 pages/day               |
# | Execute System Test Cases                          | 150 test cases         | 8 test cases/day          |
# | Fix Found Defects in System Tests                  | 40 defects             | 6 defects/day             |
# | Test Fixed Defects in System Tests                 | 40 defects             | 8 defects/day             |
# | **User Acceptance Testing (UAT)**                  |                        |                           |
# | Prepare UAT Plan                                   | 30 pages               | 4 pages/day               |
# | Conduct UAT Sessions                               | 5 sessions             | 1 session/day             |
# | Collect Feedback from UAT                          | 5 sessions             | 1 session/day             |
# | Address UAT Feedback                               | 20 defects             | 5 defects/day             |
# | **Documentation**                                  |                        |                           |
# | Write Test Summary Report                          | 20 pages               | 4 pages/day               |
# | Review Test Summary Report                         | 20 pages               | 5 pages/hour              |
# | Rework Test Summary Report                         | 10 defects             | 6 defects/hour            |
#
# ### Notes:
# - The tasks are broken down into unit testing, integration testing, system testing, user acceptance testing, and documentation.
# - The estimated work amounts and productivity rates are based on realistic expectations for a Test Engineer's workload.
# - The estimates can be adjusted based on team capacity, complexity of the system, and specific project timelines.
# Tasks for test_engineer saved to 'test_engineer_tasks_exp6.txt'
#
# Generating tasks for: documentation_engineer
#
# === Documentation Engineer Tasks and Estimates Preview ===
# Here is a structured table detailing the documentation tasks and estimates for the Chicago WideCast Smart-Home Services system, formatted similarly to the provided sample:
#
# | Task Description                                   | Amount of Work         | Productivity Rate         |
# |----------------------------------------------------|------------------------|---------------------------|
# | **User Manuals**                                   |                        |                           |
# | Write User Manual for Online TV Plans              | 30 pages               | 4 pages/Hour             |
# | Write User Manual for Data Plans                   | 25 pages               | 4 pages/Hour             |
# | Write User Manual for On-Demand Movie Streaming    | 20 pages               | 4 pages/Hour             |
# | Write User Manual for PPV Services                 | 15 pages               | 4 pages/Hour             |
# | Write User Manual for Online Video Games           | 20 pages               | 4 pages/Hour             |
# | Write User Manual for Home Security Services       | 15 pages               | 4 pages/Hour             |
# | Write User Manual for Utilities                     | 10 pages               | 4 pages/Hour             |
# | Review User Manuals                                | 6 manuals              | 3 manuals/Hour           |
# | Rework User Manuals (defects)                      | 50 defects             | 8 defects/Hour           |
# | **System Documentation**                            |                        |                           |
# | Write System Overview Document                      | 20 pages               | 5 pages/Hour             |
# | Write Technical Architecture Document               | 25 pages               | 4 pages/Hour             |
# | Write Business Process Workflows Document          | 30 pages               | 4 pages/Hour             |
# | Review System Documentation                         | 3 documents            | 2 documents/Hour         |
# | Rework System Documentation (defects)              | 30 defects             | 6 defects/Hour           |
# | **API Documentation**                               |                        |                           |
# | Write API Reference Guide                           | 40 pages               | 4 pages/Hour             |
# | Write API Usage Examples                            | 15 pages               | 4 pages/Hour             |
# | Review API Documentation                            | 2 documents            | 2 documents/Hour         |
# | Rework API Documentation (defects)                 | 20 defects             | 6 defects/Hour           |
# | **Training Materials**                              |                        |                           |
# | Create Training Manual for Managers                 | 25 pages               | 4 pages/Hour             |
# | Create Training Manual for Account Specialists      | 20 pages               | 4 pages/Hour             |
# | Create Training Manual for Technical Support        | 20 pages               | 4 pages/Hour             |
# | Create Customer Training Guide                      | 15 pages               | 4 pages/Hour             |
# | Review Training Materials                           | 4 manuals              | 2 manuals/Hour           |
# | Rework Training Materials (defects)                | 25 defects             | 6 defects/Hour           |
# | **Total Estimates**                                 |                        |                           |
# | Total Pages Written                                 | 380 pages              |                           |
# | Total Manuals Reviewed                              | 15 manuals             |                           |
# | Total Defects to Rework                            | 175 defects            |                           |
#
# ### Notes:
# - The tasks are categorized into User Manuals, System Documentation, API Documentation, and Training Materials to ensure clarity and organization.
# - The productivity rates are based on realistic expectations for a Documentation Engineer, considering the complexity of the content and the need for thoroughness in documentation.
# - The total estimates provide a comprehensive overview of the expected workload and time commitment for the documentation process.
# Tasks for documentation_engineer saved to 'documentation_engineer_tasks_exp6.txt'

# %%
# Create a comprehensive project plan
def create_project_plan(tasks_and_estimates, tagged_requirements):
    project_plan = f"""
    # Chicago WideCast Smart-Home Services Project Plan (Experiment 6)
    
    ## Tagged Requirements
    {tagged_requirements}
    
    ## Project Tasks and Estimates
    
    ### Project Manager
    {tasks_and_estimates.get("project_manager", "Not available")}
    
    ### Requirements Engineer
    {tasks_and_estimates.get("requirements_engineer", "Not available")}
    
    ### System Engineer
    {tasks_and_estimates.get("system_engineer", "Not available")}
    
    ### Software Engineer
    {tasks_and_estimates.get("software_engineer", "Not available")}
    
    ### Test Engineer
    {tasks_and_estimates.get("test_engineer", "Not available")}
    
    ### Documentation Engineer
    {tasks_and_estimates.get("documentation_engineer", "Not available")}
    """
    
    return project_plan

# Create the project plan
project_plan = create_project_plan(tasks_and_estimates, tagged_requirements)

# Save the project plan to a file
with open("Chicago_WideCast_Project_Plan_Exp6.md", "w") as f:
    f.write(project_plan)

print("\nProject plan has been saved to 'Chicago_WideCast_Project_Plan_Exp6.md'")
